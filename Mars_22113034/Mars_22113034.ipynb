# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import librosa
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2, l1
from tensorflow.keras.callbacks import EarlyStopping
import pandas as pd

# %%
data_path = '/content/drive/MyDrive/Mars'

# %%
parent_folders = ['Audio_Speech_Actors_01-24', 'Audio_Song_Actors_01-24']

# %%
# Map RAVDESS emotion IDs to emotion labels
emotion_map = {
    "01": "neutral",
    "02": "calm",
    "03": "happy",
    "04": "sad",
    "05": "angry",
    "06": "fearful",
    "07": "disgust",
    "08": "surprised"
}

def get_emotion_from_filename(filename):
    """
    Extracts emotion label from RAVDESS-style filename.
    Example filename: '03-01-05-02-02-02-12.wav'
    """
    try:
        parts = filename.split("-")
        if len(parts) >= 3:
            emotion_id = parts[2]
            return emotion_map.get(emotion_id, None)
        else:
            return None
    except Exception as e:
        print(f"⚠️ Error parsing filename {filename}: {e}")
        return None

# %%
import librosa
import numpy as np

def pitch_shift(y, sr, n_steps):
    return librosa.effects.pitch_shift(y, sr=sr, n_steps=n_steps)

def time_stretch(y, rate):
    return librosa.effects.time_stretch(y, rate)

# %%
import librosa
import numpy as np

def extract_features(file_path, duration=3, sr=22050):
    """
    Extracts audio features from a .wav file for emotion classification.

    Parameters:
        file_path (str): Path to the WAV file.
        duration (int): Audio length to standardize in seconds.
        sr (int): Sampling rate.

    Returns:
        np.ndarray: 1D array of 194 extracted features, or None on failure.
    """
    try:
        # Load and trim/pad audio
        y, sr = librosa.load(file_path, sr=sr)
        desired_len = duration * sr
        if len(y) < desired_len:
            y = np.pad(y, (0, desired_len - len(y)))
        else:
            y = y[:desired_len]

        features = []

        # MFCC (40)
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)
        features.extend(np.mean(mfcc, axis=1))

        # Chroma (12)
        stft = np.abs(librosa.stft(y))
        chroma = librosa.feature.chroma_stft(S=stft, sr=sr)
        features.extend(np.mean(chroma, axis=1))

        # Mel Spectrogram (128)
        mel = librosa.feature.melspectrogram(y=y, sr=sr)
        features.extend(np.mean(mel, axis=1))

        # Spectral Contrast (7)
        contrast = librosa.feature.spectral_contrast(S=stft, sr=sr)
        features.extend(np.mean(contrast, axis=1))

        # Tonnetz (6)
        tonnetz = librosa.feature.tonnetz(y=librosa.effects.harmonic(y), sr=sr)
        features.extend(np.mean(tonnetz, axis=1))

        # Spectral Flatness (1)
        flatness = librosa.feature.spectral_flatness(y=y)
        features.append(np.mean(flatness))

        # Validate final feature length
        if len(features) != 194:
            print(f"⚠️ Feature length mismatch for {file_path}: got {len(features)}")
            return None

        return np.array(features, dtype=np.float32)

    except Exception as e:
        print(f"❌ Failed to extract features from {file_path}: {e}")
        return None

# %%
import os
import numpy as np
import librosa
from tqdm import tqdm

# Define dataset path
data_path = '/content/drive/MyDrive/Mars'

# Parent folders
parent_folders = ['Audio_Speech_Actors_01-24', 'Audio_Song_Actors_01-24']

# Feature and label lists
X, y = [], []

# Count total files for accurate progress bar
total_files = 0
for parent in parent_folders:
    parent_path = os.path.join(data_path, parent)
    for actor_folder in os.listdir(parent_path):
        actor_path = os.path.join(parent_path, actor_folder)
        if os.path.isdir(actor_path):
            total_files += len([f for f in os.listdir(actor_path) if f.endswith('.wav')])

# Feature extraction with progress bar
print("🔍 Extracting features from audio files...")
with tqdm(total=total_files, desc="📦 Processing", unit="file") as pbar:
    for parent in parent_folders:
        parent_path = os.path.join(data_path, parent)
        for actor_folder in os.listdir(parent_path):
            actor_path = os.path.join(parent_path, actor_folder)
            if not os.path.isdir(actor_path):
                continue
            for file in os.listdir(actor_path):
                if file.endswith('.wav'):
                    full_path = os.path.join(actor_path, file)
                    emotion = get_emotion_from_filename(file)
                    features = extract_features(full_path)
                    if features is not None and emotion is not None:
                        X.append(features)
                        y.append(emotion)
                    pbar.update(1)

# Convert to arrays
X = np.array(X)
y = np.array(y)

# Final output summary
print("✅ Feature extraction complete!")
print("🎯 Total samples:", len(X))
print("📐 Feature shape:", X.shape)
print("🏷️ Labels shape:", y.shape)
# Out:
# 🔍 Extracting features from audio files...
# 📦 Processing: 100%|██████████| 2452/2452 [31:46<00:00,  1.29file/s]
# ✅ Feature extraction complete!
# 🎯 Total samples: 2452
# 📐 Feature shape: (2452, 194)
# 🏷️ Labels shape: (2452,)

# %%
X = np.array(X)
y = np.array(y)

print("✅ Feature shape:", X.shape)
print("✅ Label shape:", y.shape)
# Out:
# ✅ Feature shape: (2452, 194)
# ✅ Label shape: (2452,)

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split

X = np.array(X)
y = np.array(y_encoded)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
print(X_train.shape)
# Out:
# (1961, 194)

# %%
pca = PCA(n_components=97, svd_solver='full')
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

print("✅ Final feature shape after PCA:", X_train_pca.shape)
# Out:
# ✅ Final feature shape after PCA: (1961, 97)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.regularizers import l2
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# ⚖️ Compute class weights if needed (can be omitted after SMOTE)
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights = dict(enumerate(class_weights))

# ✅ Callbacks
early_stop = EarlyStopping(monitor='val_accuracy', patience=15, restore_best_weights=True, mode='max', verbose=1)
lr_scheduler = ReduceLROnPlateau(monitor='val_accuracy', patience=5, factor=0.5, min_lr=1e-6, mode='max', verbose=1)
model_checkpoint = ModelCheckpoint('best_model_v3.h5', monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)

# ✅ Improved Architecture
model = Sequential([
    Dense(512, activation='relu', input_shape=(X_train_pca.shape[1],), kernel_initializer='he_uniform'),
    BatchNormalization(),
    Dropout(0.6),

    Dense(256, activation='relu', kernel_initializer='he_uniform'),
    BatchNormalization(),
    Dropout(0.4),

    Dense(128, activation='relu', kernel_initializer='he_uniform'),
    BatchNormalization(),
    Dropout(0.4),

    Dense(64, activation='relu', kernel_initializer='he_uniform'),
    Dropout(0.2),

    Dense(8, activation='softmax')
])


# ✅ Compile
model.compile(
    optimizer=AdamW(learning_rate=0.0005, weight_decay=5e-5),
    loss=SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# ✅ Train
history = model.fit(
    X_train_pca, y_train,
    validation_data=(X_test_pca, y_test),
    epochs=300,
    batch_size=32,
    verbose=1
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.1336 - loss: 3.0030 - val_accuracy: 0.1752 - val_loss: 2.0333
# Epoch 2/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2137 - loss: 2.4651 - val_accuracy: 0.2301 - val_loss: 1.9577
# Epoch 3/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.2653 - loss: 2.1510 - val_accuracy: 0.3299 - val_loss: 1.8761
# Epoch 4/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3047 - loss: 2.0647 - val_accuracy: 0.3829 - val_loss: 1.7918
# Epoch 5/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.3214 - loss: 1.8811 - val_accuracy: 0.4277 - val_loss: 1.6741
# Epoch 6/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3463 - loss: 1.7572 - val_accuracy: 0.4521 - val_loss: 1.5517
# Epoch 7/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.3841 - loss: 1.6747 - val_accuracy: 0.4603 - val_loss: 1.4338
# Epoch 8/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.3592 - loss: 1.6659 - val_accuracy: 0.4990 - val_loss: 1.3565
# Epoch 9/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4061 - loss: 1.5777 - val_accuracy: 0.4868 - val_loss: 1.3123
# Epoch 10/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.3960 - loss: 1.5877 - val_accuracy: 0.5193 - val_loss: 1.2617
# Epoch 11/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4234 - loss: 1.5035 - val_accuracy: 0.5336 - val_loss: 1.2388
# Epoch 12/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4821 - loss: 1.4369 - val_accuracy: 0.5438 - val_loss: 1.2133
# Epoch 13/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4696 - loss: 1.3878 - val_accuracy: 0.5295 - val_loss: 1.2076
# Epoch 14/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4624 - loss: 1.4065 - val_accuracy: 0.5580 - val_loss: 1.1675
# Epoch 15/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4867 - loss: 1.3847 - val_accuracy: 0.5377 - val_loss: 1.1541
# Epoch 16/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4672 - loss: 1.4064 - val_accuracy: 0.5642 - val_loss: 1.1325
# Epoch 17/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4870 - loss: 1.3369 - val_accuracy: 0.5682 - val_loss: 1.1190
# Epoch 18/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4873 - loss: 1.3636 - val_accuracy: 0.5723 - val_loss: 1.1107
# Epoch 19/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5186 - loss: 1.3070 - val_accuracy: 0.5764 - val_loss: 1.1088
# Epoch 20/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5401 - loss: 1.2318 - val_accuracy: 0.5845 - val_loss: 1.0970
# Epoch 21/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5224 - loss: 1.2551 - val_accuracy: 0.5886 - val_loss: 1.0855
# Epoch 22/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5355 - loss: 1.2176 - val_accuracy: 0.5866 - val_loss: 1.0686
# Epoch 23/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5312 - loss: 1.2167 - val_accuracy: 0.5947 - val_loss: 1.0649
# Epoch 24/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5110 - loss: 1.2571 - val_accuracy: 0.5947 - val_loss: 1.0561
# Epoch 25/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5429 - loss: 1.2287 - val_accuracy: 0.5947 - val_loss: 1.0443
# Epoch 26/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5380 - loss: 1.1630 - val_accuracy: 0.6029 - val_loss: 1.0409
# Epoch 27/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5648 - loss: 1.1399 - val_accuracy: 0.6069 - val_loss: 1.0209
# Epoch 28/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5588 - loss: 1.1287 - val_accuracy: 0.6029 - val_loss: 1.0145
# Epoch 29/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5595 - loss: 1.1587 - val_accuracy: 0.6110 - val_loss: 1.0069
# Epoch 30/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5921 - loss: 1.1114 - val_accuracy: 0.6191 - val_loss: 0.9965
# Epoch 31/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5628 - loss: 1.1080 - val_accuracy: 0.6049 - val_loss: 0.9914
# Epoch 32/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6152 - loss: 1.0062 - val_accuracy: 0.6069 - val_loss: 0.9820
# Epoch 33/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5965 - loss: 1.0575 - val_accuracy: 0.6130 - val_loss: 0.9799
# Epoch 34/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6026 - loss: 1.0187 - val_accuracy: 0.6151 - val_loss: 0.9711
# Epoch 35/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6266 - loss: 1.0307 - val_accuracy: 0.6232 - val_loss: 0.9561
# Epoch 36/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6171 - loss: 1.0536 - val_accuracy: 0.6253 - val_loss: 0.9526
# Epoch 37/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6256 - loss: 0.9819 - val_accuracy: 0.6314 - val_loss: 0.9468
# Epoch 38/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6323 - loss: 1.0113 - val_accuracy: 0.6456 - val_loss: 0.9316
# Epoch 39/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6056 - loss: 1.0142 - val_accuracy: 0.6354 - val_loss: 0.9423
# Epoch 40/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6282 - loss: 1.0015 - val_accuracy: 0.6314 - val_loss: 0.9344
# Epoch 41/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6435 - loss: 0.9708 - val_accuracy: 0.6599 - val_loss: 0.9117
# Epoch 42/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6445 - loss: 0.9704 - val_accuracy: 0.6456 - val_loss: 0.9108
# Epoch 43/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6400 - loss: 0.9428 - val_accuracy: 0.6517 - val_loss: 0.8980
# Epoch 44/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6651 - loss: 0.9147 - val_accuracy: 0.6619 - val_loss: 0.8941
# Epoch 45/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6350 - loss: 0.9137 - val_accuracy: 0.6721 - val_loss: 0.8839
# Epoch 46/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6324 - loss: 0.9361 - val_accuracy: 0.6823 - val_loss: 0.8776
# Epoch 47/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6893 - loss: 0.8640 - val_accuracy: 0.6660 - val_loss: 0.8838
# Epoch 48/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6745 - loss: 0.8853 - val_accuracy: 0.6701 - val_loss: 0.8794
# Epoch 49/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6629 - loss: 0.9252 - val_accuracy: 0.6762 - val_loss: 0.8771
# Epoch 50/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6624 - loss: 0.8905 - val_accuracy: 0.6762 - val_loss: 0.8586
# Epoch 51/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6817 - loss: 0.8756 - val_accuracy: 0.6741 - val_loss: 0.8508
# Epoch 52/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6710 - loss: 0.8586 - val_accuracy: 0.6802 - val_loss: 0.8541
# Epoch 53/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6994 - loss: 0.8441 - val_accuracy: 0.6802 - val_loss: 0.8590
# Epoch 54/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6846 - loss: 0.8033 - val_accuracy: 0.6965 - val_loss: 0.8443
# Epoch 55/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6673 - loss: 0.8529 - val_accuracy: 0.6965 - val_loss: 0.8403
# Epoch 56/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6885 - loss: 0.8303 - val_accuracy: 0.6904 - val_loss: 0.8340
# Epoch 57/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6908 - loss: 0.8201 - val_accuracy: 0.6864 - val_loss: 0.8350
# Epoch 58/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6761 - loss: 0.8082 - val_accuracy: 0.7047 - val_loss: 0.8301
# Epoch 59/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6978 - loss: 0.7988 - val_accuracy: 0.7026 - val_loss: 0.8122
# Epoch 60/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6992 - loss: 0.8207 - val_accuracy: 0.7047 - val_loss: 0.8134
# Epoch 61/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7063 - loss: 0.7624 - val_accuracy: 0.7088 - val_loss: 0.8159
# Epoch 62/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6974 - loss: 0.7976 - val_accuracy: 0.7047 - val_loss: 0.8116
# Epoch 63/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7183 - loss: 0.7561 - val_accuracy: 0.7047 - val_loss: 0.8003
# Epoch 64/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7192 - loss: 0.7577 - val_accuracy: 0.7149 - val_loss: 0.8011
# Epoch 65/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7378 - loss: 0.7143 - val_accuracy: 0.7230 - val_loss: 0.7976
# Epoch 66/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7438 - loss: 0.6896 - val_accuracy: 0.7108 - val_loss: 0.7921
# Epoch 67/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7102 - loss: 0.7979 - val_accuracy: 0.7026 - val_loss: 0.7923
# Epoch 68/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7067 - loss: 0.7491 - val_accuracy: 0.6986 - val_loss: 0.7995
# Epoch 69/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7397 - loss: 0.6982 - val_accuracy: 0.7128 - val_loss: 0.7978
# Epoch 70/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7114 - loss: 0.7695 - val_accuracy: 0.7230 - val_loss: 0.7887
# Epoch 71/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7405 - loss: 0.7464 - val_accuracy: 0.7271 - val_loss: 0.7563
# Epoch 72/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7458 - loss: 0.6705 - val_accuracy: 0.7251 - val_loss: 0.7683
# Epoch 73/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7329 - loss: 0.7262 - val_accuracy: 0.7169 - val_loss: 0.7760
# Epoch 74/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7438 - loss: 0.6769 - val_accuracy: 0.7271 - val_loss: 0.7572
# Epoch 75/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7551 - loss: 0.6744 - val_accuracy: 0.7210 - val_loss: 0.7771
# Epoch 76/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7615 - loss: 0.6533 - val_accuracy: 0.7189 - val_loss: 0.7699
# Epoch 77/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7532 - loss: 0.6461 - val_accuracy: 0.7088 - val_loss: 0.7718
# Epoch 78/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7394 - loss: 0.6588 - val_accuracy: 0.7088 - val_loss: 0.7861
# Epoch 79/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7650 - loss: 0.6418 - val_accuracy: 0.7067 - val_loss: 0.7790
# Epoch 80/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7633 - loss: 0.6122 - val_accuracy: 0.7230 - val_loss: 0.7832
# Epoch 81/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7825 - loss: 0.6208 - val_accuracy: 0.7251 - val_loss: 0.7696
# Epoch 82/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7517 - loss: 0.6719 - val_accuracy: 0.7312 - val_loss: 0.7877
# Epoch 83/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7686 - loss: 0.5855 - val_accuracy: 0.7210 - val_loss: 0.7579
# Epoch 84/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7765 - loss: 0.5953 - val_accuracy: 0.7271 - val_loss: 0.7670
# Epoch 85/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7889 - loss: 0.5648 - val_accuracy: 0.7352 - val_loss: 0.7749
# Epoch 86/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7748 - loss: 0.6007 - val_accuracy: 0.7332 - val_loss: 0.7626
# Epoch 87/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7970 - loss: 0.5867 - val_accuracy: 0.7393 - val_loss: 0.7426
# Epoch 88/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7780 - loss: 0.5581 - val_accuracy: 0.7434 - val_loss: 0.7382
# Epoch 89/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7707 - loss: 0.5890 - val_accuracy: 0.7413 - val_loss: 0.7413
# Epoch 90/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7907 - loss: 0.5687 - val_accuracy: 0.7434 - val_loss: 0.7484
# Epoch 91/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8031 - loss: 0.5348 - val_accuracy: 0.7576 - val_loss: 0.7330
# Epoch 92/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7852 - loss: 0.5651 - val_accuracy: 0.7576 - val_loss: 0.7382
# Epoch 93/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7925 - loss: 0.5690 - val_accuracy: 0.7515 - val_loss: 0.7267
# Epoch 94/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7951 - loss: 0.5594 - val_accuracy: 0.7617 - val_loss: 0.7366
# Epoch 95/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7792 - loss: 0.6125 - val_accuracy: 0.7515 - val_loss: 0.7436
# Epoch 96/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7967 - loss: 0.5552 - val_accuracy: 0.7637 - val_loss: 0.7340
# Epoch 97/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8096 - loss: 0.5105 - val_accuracy: 0.7475 - val_loss: 0.7215
# Epoch 98/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8064 - loss: 0.5165 - val_accuracy: 0.7617 - val_loss: 0.7283
# Epoch 99/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8439 - loss: 0.4483 - val_accuracy: 0.7454 - val_loss: 0.7342
# Epoch 100/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7879 - loss: 0.5622 - val_accuracy: 0.7454 - val_loss: 0.7454
# Epoch 101/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8224 - loss: 0.5000 - val_accuracy: 0.7556 - val_loss: 0.7385
# Epoch 102/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8173 - loss: 0.4859 - val_accuracy: 0.7556 - val_loss: 0.7275
# Epoch 103/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8250 - loss: 0.4945 - val_accuracy: 0.7617 - val_loss: 0.7267
# Epoch 104/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8220 - loss: 0.5407 - val_accuracy: 0.7678 - val_loss: 0.7116
# Epoch 105/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8318 - loss: 0.4510 - val_accuracy: 0.7658 - val_loss: 0.7200
# Epoch 106/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8294 - loss: 0.4606 - val_accuracy: 0.7576 - val_loss: 0.7311
# Epoch 107/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8281 - loss: 0.4681 - val_accuracy: 0.7576 - val_loss: 0.7268
# Epoch 108/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8172 - loss: 0.4785 - val_accuracy: 0.7495 - val_loss: 0.7333
# Epoch 109/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8416 - loss: 0.4549 - val_accuracy: 0.7576 - val_loss: 0.7319
# Epoch 110/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8392 - loss: 0.4352 - val_accuracy: 0.7556 - val_loss: 0.7461
# Epoch 111/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8588 - loss: 0.3880 - val_accuracy: 0.7617 - val_loss: 0.7408
# Epoch 112/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8275 - loss: 0.4739 - val_accuracy: 0.7576 - val_loss: 0.7392
# Epoch 113/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8501 - loss: 0.4301 - val_accuracy: 0.7678 - val_loss: 0.7435
# Epoch 114/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8492 - loss: 0.4436 - val_accuracy: 0.7699 - val_loss: 0.7190
# Epoch 115/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8340 - loss: 0.4481 - val_accuracy: 0.7678 - val_loss: 0.7094
# Epoch 116/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8582 - loss: 0.3938 - val_accuracy: 0.7719 - val_loss: 0.7218
# Epoch 117/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8416 - loss: 0.4508 - val_accuracy: 0.7719 - val_loss: 0.7434
# Epoch 118/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8423 - loss: 0.4200 - val_accuracy: 0.7699 - val_loss: 0.7372
# Epoch 119/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8452 - loss: 0.4454 - val_accuracy: 0.7719 - val_loss: 0.7197
# Epoch 120/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8527 - loss: 0.4248 - val_accuracy: 0.7678 - val_loss: 0.7406
# Epoch 121/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8640 - loss: 0.3815 - val_accuracy: 0.7760 - val_loss: 0.7238
# Epoch 122/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8577 - loss: 0.4061 - val_accuracy: 0.7800 - val_loss: 0.7231
# Epoch 123/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8594 - loss: 0.3924 - val_accuracy: 0.7739 - val_loss: 0.7259
# Epoch 124/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8506 - loss: 0.4055 - val_accuracy: 0.7882 - val_loss: 0.7244
# Epoch 125/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8509 - loss: 0.4027 - val_accuracy: 0.7780 - val_loss: 0.7095
# Epoch 126/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8609 - loss: 0.3725 - val_accuracy: 0.7780 - val_loss: 0.7292
# Epoch 127/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8716 - loss: 0.3853 - val_accuracy: 0.7760 - val_loss: 0.7411
# Epoch 128/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8828 - loss: 0.3567 - val_accuracy: 0.7841 - val_loss: 0.7504
# Epoch 129/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8732 - loss: 0.3451 - val_accuracy: 0.7882 - val_loss: 0.7480
# Epoch 130/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8844 - loss: 0.3449 - val_accuracy: 0.7963 - val_loss: 0.7464
# Epoch 131/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8596 - loss: 0.3840 - val_accuracy: 0.7862 - val_loss: 0.7299
# Epoch 132/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8675 - loss: 0.3839 - val_accuracy: 0.7841 - val_loss: 0.7113
# Epoch 133/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8745 - loss: 0.3791 - val_accuracy: 0.7821 - val_loss: 0.7373
# Epoch 134/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8682 - loss: 0.3541 - val_accuracy: 0.7984 - val_loss: 0.7514
# Epoch 135/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8772 - loss: 0.3314 - val_accuracy: 0.7963 - val_loss: 0.7488
# Epoch 136/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8848 - loss: 0.3373 - val_accuracy: 0.7841 - val_loss: 0.7434
# Epoch 137/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8859 - loss: 0.3357 - val_accuracy: 0.7841 - val_loss: 0.7574
# Epoch 138/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8905 - loss: 0.3242 - val_accuracy: 0.7902 - val_loss: 0.7604
# Epoch 139/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8758 - loss: 0.3310 - val_accuracy: 0.7862 - val_loss: 0.7504
# Epoch 140/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8946 - loss: 0.3133 - val_accuracy: 0.7902 - val_loss: 0.7525
# Epoch 141/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8836 - loss: 0.3393 - val_accuracy: 0.7923 - val_loss: 0.7594
# Epoch 142/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8755 - loss: 0.3621 - val_accuracy: 0.7943 - val_loss: 0.7380
# Epoch 143/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8819 - loss: 0.3237 - val_accuracy: 0.7862 - val_loss: 0.7373
# Epoch 144/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8872 - loss: 0.3257 - val_accuracy: 0.7882 - val_loss: 0.7410
# Epoch 145/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8998 - loss: 0.2835 - val_accuracy: 0.7963 - val_loss: 0.7549
# Epoch 146/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8789 - loss: 0.3433 - val_accuracy: 0.7984 - val_loss: 0.7509
# Epoch 147/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8976 - loss: 0.3144 - val_accuracy: 0.7882 - val_loss: 0.7506
# Epoch 148/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8681 - loss: 0.3701 - val_accuracy: 0.7902 - val_loss: 0.7477
# Epoch 149/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9054 - loss: 0.2854 - val_accuracy: 0.8024 - val_loss: 0.7558
# Epoch 150/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8969 - loss: 0.2864 - val_accuracy: 0.7943 - val_loss: 0.7671
# Epoch 151/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8749 - loss: 0.3478 - val_accuracy: 0.8086 - val_loss: 0.7753
# Epoch 152/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9021 - loss: 0.2813 - val_accuracy: 0.8065 - val_loss: 0.7424
# Epoch 153/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9083 - loss: 0.2733 - val_accuracy: 0.7923 - val_loss: 0.7481
# Epoch 154/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8963 - loss: 0.2855 - val_accuracy: 0.7963 - val_loss: 0.7441
# Epoch 155/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9027 - loss: 0.2900 - val_accuracy: 0.7902 - val_loss: 0.7768
# Epoch 156/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8989 - loss: 0.2880 - val_accuracy: 0.7943 - val_loss: 0.7495
# Epoch 157/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9048 - loss: 0.2912 - val_accuracy: 0.8024 - val_loss: 0.7492
# Epoch 158/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8882 - loss: 0.3100 - val_accuracy: 0.7963 - val_loss: 0.7609
# Epoch 159/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8994 - loss: 0.2854 - val_accuracy: 0.8004 - val_loss: 0.7573
# Epoch 160/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9046 - loss: 0.2781 - val_accuracy: 0.7943 - val_loss: 0.7815
# Epoch 161/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8912 - loss: 0.3016 - val_accuracy: 0.8004 - val_loss: 0.7463
# Epoch 162/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8956 - loss: 0.3052 - val_accuracy: 0.8126 - val_loss: 0.7342
# Epoch 163/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8985 - loss: 0.2782 - val_accuracy: 0.8106 - val_loss: 0.7423
# Epoch 164/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9077 - loss: 0.2689 - val_accuracy: 0.8045 - val_loss: 0.7489
# Epoch 165/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9011 - loss: 0.3032 - val_accuracy: 0.8024 - val_loss: 0.7547
# Epoch 166/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8871 - loss: 0.3394 - val_accuracy: 0.8024 - val_loss: 0.7380
# Epoch 167/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9045 - loss: 0.2727 - val_accuracy: 0.8024 - val_loss: 0.7375
# Epoch 168/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8962 - loss: 0.2963 - val_accuracy: 0.7943 - val_loss: 0.7389
# Epoch 169/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9021 - loss: 0.2545 - val_accuracy: 0.8004 - val_loss: 0.7337
# Epoch 170/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9234 - loss: 0.2187 - val_accuracy: 0.8126 - val_loss: 0.7500
# Epoch 171/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9100 - loss: 0.2605 - val_accuracy: 0.8106 - val_loss: 0.7373
# Epoch 172/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9095 - loss: 0.2547 - val_accuracy: 0.8086 - val_loss: 0.7270
# Epoch 173/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9012 - loss: 0.2761 - val_accuracy: 0.8024 - val_loss: 0.7307
# Epoch 174/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9049 - loss: 0.2666 - val_accuracy: 0.8106 - val_loss: 0.7245
# Epoch 175/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9258 - loss: 0.2228 - val_accuracy: 0.8086 - val_loss: 0.7616
# Epoch 176/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9248 - loss: 0.2248 - val_accuracy: 0.8086 - val_loss: 0.7420
# Epoch 177/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9171 - loss: 0.2398 - val_accuracy: 0.8126 - val_loss: 0.7659
# Epoch 178/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9075 - loss: 0.2340 - val_accuracy: 0.8147 - val_loss: 0.7758
# Epoch 179/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9049 - loss: 0.2786 - val_accuracy: 0.8126 - val_loss: 0.7616
# Epoch 180/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9130 - loss: 0.2301 - val_accuracy: 0.8126 - val_loss: 0.7669
# Epoch 181/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9151 - loss: 0.2605 - val_accuracy: 0.8147 - val_loss: 0.7487
# Epoch 182/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9138 - loss: 0.2271 - val_accuracy: 0.8065 - val_loss: 0.7567
# Epoch 183/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9193 - loss: 0.2141 - val_accuracy: 0.8065 - val_loss: 0.7728
# Epoch 184/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9227 - loss: 0.2136 - val_accuracy: 0.8147 - val_loss: 0.7685
# Epoch 185/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9246 - loss: 0.2350 - val_accuracy: 0.8086 - val_loss: 0.7714
# Epoch 186/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9119 - loss: 0.2210 - val_accuracy: 0.8086 - val_loss: 0.7665
# Epoch 187/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9086 - loss: 0.2673 - val_accuracy: 0.8065 - val_loss: 0.7800
# Epoch 188/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9163 - loss: 0.2282 - val_accuracy: 0.8147 - val_loss: 0.7774
# Epoch 189/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9242 - loss: 0.2246 - val_accuracy: 0.8106 - val_loss: 0.7717
# Epoch 190/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9081 - loss: 0.2665 - val_accuracy: 0.8086 - val_loss: 0.7617
# Epoch 191/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9157 - loss: 0.2402 - val_accuracy: 0.8106 - val_loss: 0.7529
# Epoch 192/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9306 - loss: 0.1948 - val_accuracy: 0.8106 - val_loss: 0.7630
# Epoch 193/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9214 - loss: 0.2148 - val_accuracy: 0.8126 - val_loss: 0.7819
# Epoch 194/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9276 - loss: 0.2245 - val_accuracy: 0.8208 - val_loss: 0.7470
# Epoch 195/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9380 - loss: 0.1833 - val_accuracy: 0.8289 - val_loss: 0.7514
# Epoch 196/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9364 - loss: 0.2098 - val_accuracy: 0.8126 - val_loss: 0.7724
# Epoch 197/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9323 - loss: 0.1937 - val_accuracy: 0.8187 - val_loss: 0.7602
# Epoch 198/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9092 - loss: 0.2452 - val_accuracy: 0.8126 - val_loss: 0.7719
# Epoch 199/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9312 - loss: 0.2108 - val_accuracy: 0.8004 - val_loss: 0.7682
# Epoch 200/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9345 - loss: 0.1995 - val_accuracy: 0.8126 - val_loss: 0.7656
# Epoch 201/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9277 - loss: 0.2072 - val_accuracy: 0.8045 - val_loss: 0.8016
# Epoch 202/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9159 - loss: 0.2359 - val_accuracy: 0.8065 - val_loss: 0.7980
# Epoch 203/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9382 - loss: 0.1885 - val_accuracy: 0.8045 - val_loss: 0.7723
# Epoch 204/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9242 - loss: 0.2043 - val_accuracy: 0.7923 - val_loss: 0.7842
# Epoch 205/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9415 - loss: 0.1770 - val_accuracy: 0.7984 - val_loss: 0.7840
# Epoch 206/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9271 - loss: 0.2030 - val_accuracy: 0.8147 - val_loss: 0.7850
# Epoch 207/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9445 - loss: 0.1603 - val_accuracy: 0.7963 - val_loss: 0.7966
# Epoch 208/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9502 - loss: 0.1749 - val_accuracy: 0.7902 - val_loss: 0.8105
# Epoch 209/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9286 - loss: 0.1921 - val_accuracy: 0.8024 - val_loss: 0.8019
# Epoch 210/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9362 - loss: 0.1852 - val_accuracy: 0.8065 - val_loss: 0.7868
# Epoch 211/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9213 - loss: 0.2185 - val_accuracy: 0.8086 - val_loss: 0.7761
# Epoch 212/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9400 - loss: 0.1714 - val_accuracy: 0.8167 - val_loss: 0.7693
# Epoch 213/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9427 - loss: 0.1696 - val_accuracy: 0.8106 - val_loss: 0.7615
# Epoch 214/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9320 - loss: 0.2121 - val_accuracy: 0.8167 - val_loss: 0.7752
# Epoch 215/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9243 - loss: 0.2247 - val_accuracy: 0.8086 - val_loss: 0.7911
# Epoch 216/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9346 - loss: 0.1896 - val_accuracy: 0.8024 - val_loss: 0.7885
# Epoch 217/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9467 - loss: 0.1552 - val_accuracy: 0.8147 - val_loss: 0.7779
# Epoch 218/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9409 - loss: 0.1748 - val_accuracy: 0.8147 - val_loss: 0.7856
# Epoch 219/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9383 - loss: 0.1813 - val_accuracy: 0.8228 - val_loss: 0.8007
# Epoch 220/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9377 - loss: 0.1972 - val_accuracy: 0.8106 - val_loss: 0.7718
# Epoch 221/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9383 - loss: 0.1615 - val_accuracy: 0.8228 - val_loss: 0.7740
# Epoch 222/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9369 - loss: 0.1796 - val_accuracy: 0.8167 - val_loss: 0.7826
# Epoch 223/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9413 - loss: 0.1897 - val_accuracy: 0.8045 - val_loss: 0.8054
# Epoch 224/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9253 - loss: 0.2048 - val_accuracy: 0.8065 - val_loss: 0.7909
# Epoch 225/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9297 - loss: 0.1973 - val_accuracy: 0.8106 - val_loss: 0.7667
# Epoch 226/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9542 - loss: 0.1511 - val_accuracy: 0.8208 - val_loss: 0.7502
# Epoch 227/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9383 - loss: 0.1753 - val_accuracy: 0.8147 - val_loss: 0.7566
# Epoch 228/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9323 - loss: 0.1772 - val_accuracy: 0.8126 - val_loss: 0.7664
# Epoch 229/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9425 - loss: 0.1687 - val_accuracy: 0.8147 - val_loss: 0.7682
# Epoch 230/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9424 - loss: 0.1756 - val_accuracy: 0.8248 - val_loss: 0.7601
# Epoch 231/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9451 - loss: 0.1732 - val_accuracy: 0.8228 - val_loss: 0.7477
# Epoch 232/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9373 - loss: 0.1758 - val_accuracy: 0.8167 - val_loss: 0.7649
# Epoch 233/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9351 - loss: 0.1714 - val_accuracy: 0.8167 - val_loss: 0.7807
# Epoch 234/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9324 - loss: 0.1882 - val_accuracy: 0.8269 - val_loss: 0.7694
# Epoch 235/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9443 - loss: 0.1996 - val_accuracy: 0.8147 - val_loss: 0.8014
# Epoch 236/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9470 - loss: 0.1715 - val_accuracy: 0.8147 - val_loss: 0.7832
# Epoch 237/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9479 - loss: 0.1568 - val_accuracy: 0.8167 - val_loss: 0.7771
# Epoch 238/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9493 - loss: 0.1535 - val_accuracy: 0.8045 - val_loss: 0.8098
# Epoch 239/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9400 - loss: 0.1747 - val_accuracy: 0.8024 - val_loss: 0.8170
# Epoch 240/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9341 - loss: 0.1749 - val_accuracy: 0.8187 - val_loss: 0.8068
# Epoch 241/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9388 - loss: 0.1694 - val_accuracy: 0.8187 - val_loss: 0.7867
# Epoch 242/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9371 - loss: 0.1889 - val_accuracy: 0.8147 - val_loss: 0.8084
# Epoch 243/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9487 - loss: 0.1790 - val_accuracy: 0.8126 - val_loss: 0.8110
# Epoch 244/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9402 - loss: 0.1702 - val_accuracy: 0.8147 - val_loss: 0.7903
# Epoch 245/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9520 - loss: 0.1470 - val_accuracy: 0.8065 - val_loss: 0.8135
# Epoch 246/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9386 - loss: 0.1828 - val_accuracy: 0.8065 - val_loss: 0.8143
# Epoch 247/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9353 - loss: 0.1838 - val_accuracy: 0.8187 - val_loss: 0.7787
# Epoch 248/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9539 - loss: 0.1254 - val_accuracy: 0.8167 - val_loss: 0.7879
# Epoch 249/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9404 - loss: 0.1873 - val_accuracy: 0.8228 - val_loss: 0.7857
# Epoch 250/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9558 - loss: 0.1348 - val_accuracy: 0.8208 - val_loss: 0.7867
# Epoch 251/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9441 - loss: 0.1642 - val_accuracy: 0.8167 - val_loss: 0.7965
# Epoch 252/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9582 - loss: 0.1252 - val_accuracy: 0.8147 - val_loss: 0.8235
# Epoch 253/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9492 - loss: 0.1442 - val_accuracy: 0.8126 - val_loss: 0.8078
# Epoch 254/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9446 - loss: 0.1519 - val_accuracy: 0.8248 - val_loss: 0.7902
# Epoch 255/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9446 - loss: 0.1615 - val_accuracy: 0.8106 - val_loss: 0.7813
# Epoch 256/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9497 - loss: 0.1501 - val_accuracy: 0.8086 - val_loss: 0.8086
# Epoch 257/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9473 - loss: 0.1658 - val_accuracy: 0.8106 - val_loss: 0.7844
# Epoch 258/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9525 - loss: 0.1373 - val_accuracy: 0.8167 - val_loss: 0.7671
# Epoch 259/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9508 - loss: 0.1488 - val_accuracy: 0.8126 - val_loss: 0.7766
# Epoch 260/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9423 - loss: 0.1654 - val_accuracy: 0.8187 - val_loss: 0.7804
# Epoch 261/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9366 - loss: 0.1867 - val_accuracy: 0.8167 - val_loss: 0.7904
# Epoch 262/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9530 - loss: 0.1253 - val_accuracy: 0.8248 - val_loss: 0.7508
# Epoch 263/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9435 - loss: 0.1531 - val_accuracy: 0.8147 - val_loss: 0.7865
# Epoch 264/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9455 - loss: 0.1734 - val_accuracy: 0.8167 - val_loss: 0.7737
# Epoch 265/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9522 - loss: 0.1415 - val_accuracy: 0.8086 - val_loss: 0.8104
# Epoch 266/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9556 - loss: 0.1427 - val_accuracy: 0.8187 - val_loss: 0.8021
# Epoch 267/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9621 - loss: 0.1528 - val_accuracy: 0.8187 - val_loss: 0.7869
# Epoch 268/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9596 - loss: 0.1282 - val_accuracy: 0.8106 - val_loss: 0.7845
# Epoch 269/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9516 - loss: 0.1516 - val_accuracy: 0.8187 - val_loss: 0.7777
# Epoch 270/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9500 - loss: 0.1467 - val_accuracy: 0.8208 - val_loss: 0.7885
# Epoch 271/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9400 - loss: 0.1551 - val_accuracy: 0.8248 - val_loss: 0.7840
# Epoch 272/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9580 - loss: 0.1304 - val_accuracy: 0.8167 - val_loss: 0.7763
# Epoch 273/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9429 - loss: 0.1479 - val_accuracy: 0.8106 - val_loss: 0.7609
# Epoch 274/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9503 - loss: 0.1542 - val_accuracy: 0.8126 - val_loss: 0.7796
# Epoch 275/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9535 - loss: 0.1475 - val_accuracy: 0.8147 - val_loss: 0.7768
# Epoch 276/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9588 - loss: 0.1234 - val_accuracy: 0.8106 - val_loss: 0.7985
# Epoch 277/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9469 - loss: 0.1594 - val_accuracy: 0.8065 - val_loss: 0.7811
# Epoch 278/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9628 - loss: 0.1301 - val_accuracy: 0.8024 - val_loss: 0.8152
# Epoch 279/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9408 - loss: 0.1850 - val_accuracy: 0.8086 - val_loss: 0.7909
# Epoch 280/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9581 - loss: 0.1344 - val_accuracy: 0.7984 - val_loss: 0.7988
# Epoch 281/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9400 - loss: 0.1711 - val_accuracy: 0.8065 - val_loss: 0.7746
# Epoch 282/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9533 - loss: 0.1431 - val_accuracy: 0.8065 - val_loss: 0.7759
# Epoch 283/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9525 - loss: 0.1391 - val_accuracy: 0.8106 - val_loss: 0.7796
# Epoch 284/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9578 - loss: 0.1150 - val_accuracy: 0.8065 - val_loss: 0.7836
# Epoch 285/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9372 - loss: 0.1690 - val_accuracy: 0.8086 - val_loss: 0.7938
# Epoch 286/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9574 - loss: 0.1236 - val_accuracy: 0.8086 - val_loss: 0.8025
# Epoch 287/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9586 - loss: 0.1232 - val_accuracy: 0.8126 - val_loss: 0.8134
# Epoch 288/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9593 - loss: 0.1141 - val_accuracy: 0.8086 - val_loss: 0.8143
# Epoch 289/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9598 - loss: 0.1315 - val_accuracy: 0.7984 - val_loss: 0.8589
# Epoch 290/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9486 - loss: 0.1380 - val_accuracy: 0.8147 - val_loss: 0.8239
# Epoch 291/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9572 - loss: 0.1330 - val_accuracy: 0.8086 - val_loss: 0.8218
# Epoch 292/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9571 - loss: 0.1258 - val_accuracy: 0.8024 - val_loss: 0.8239
# Epoch 293/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9499 - loss: 0.1423 - val_accuracy: 0.8086 - val_loss: 0.8660
# Epoch 294/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9594 - loss: 0.1222 - val_accuracy: 0.8126 - val_loss: 0.8394
# Epoch 295/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9563 - loss: 0.1292 - val_accuracy: 0.7984 - val_loss: 0.8165
# Epoch 296/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9615 - loss: 0.1229 - val_accuracy: 0.8004 - val_loss: 0.8168
# Epoch 297/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9560 - loss: 0.1149 - val_accuracy: 0.8065 - val_loss: 0.8467
# Epoch 298/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9579 - loss: 0.1233 - val_accuracy: 0.8187 - val_loss: 0.8255
# Epoch 299/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9721 - loss: 0.0855 - val_accuracy: 0.8004 - val_loss: 0.8487
# Epoch 300/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9638 - loss: 0.1085 - val_accuracy: 0.8167 - val_loss: 0.8393

# %%
from sklearn.metrics import classification_report, accuracy_score

# Get predictions
y_pred = model.predict(X_test_pca)
y_pred_labels = np.argmax(y_pred, axis=1)

# Convert integer labels to strings
target_names = [str(cls) for cls in le.classes_]

# Print the report
print(classification_report(y_test, y_pred_labels, target_names=target_names))
print(f"✅ Overall Test Accuracy: {accuracy_score(y_test, y_pred_labels):.4f}")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
#               precision    recall  f1-score   support
#
#        angry       0.92      0.87      0.89        75
#         calm       0.81      0.93      0.87        75
#      disgust       0.74      0.67      0.70        39
#      fearful       0.79      0.72      0.76        75
#        happy       0.82      0.77      0.79        75
#      neutral       0.85      0.92      0.89        38
#          sad       0.83      0.76      0.79        75
#    surprised       0.72      0.92      0.81        39
#
#     accuracy                           0.82       491
#    macro avg       0.81      0.82      0.81       491
# weighted avg       0.82      0.82      0.82       491
#
# ✅ Overall Test Accuracy: 0.8167

# %%
print("✅ Model input shape:", model.input_shape)
print("✅ PCA components used:", X_train_pca.shape[1])
# Out:
# ✅ Model input shape: (None, 97)
# ✅ PCA components used: 97

# %%
import pickle

# Assuming `pca` is your already fitted PCA object
with open('pca_transform_22113034.pkl', 'wb') as f:
    pickle.dump(pca, f)

print("✅ PCA saved to 'pca_transform.pkl'")

from tensorflow.keras.models import save_model

# Assuming scaler is already fitted, and model is already trained
# Save MinMaxScaler using pickle
with open('minmax_scaler_22113034.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# Save Keras model in HDF5 format
model.save('emotion_keras_model_22113034.h5')

print("✅ Saved MinMaxScaler and Keras model.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ PCA saved to 'pca_transform.pkl'
# ✅ Saved MinMaxScaler and Keras model.

# %%
import pickle

# Load the scaler
with open("minmax_scaler_22113034.pkl", "rb") as f:
    scaler = pickle.load(f)

# Print the number of features it expects
print("✅ Scaler was trained on:", scaler.n_features_in_, "features")
# Out:
# ✅ Scaler was trained on: 194 features
